# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("/kaggle/input/dataset2/StudentPerformanceFactors (1).csv")

# %%
df.head(100)
# Out:
#     Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0              23          84                  Low                High
# 1              19          64                  Low              Medium
# 2              24          98               Medium              Medium
# 3              29          89                  Low              Medium
# 4              19          92               Medium              Medium
# ..            ...         ...                  ...                 ...
# 95             11          91               Medium              Medium
# 96             22          64                  Low              Medium
# 97             22          81               Medium              Medium
# 98             20          69                 High                High
# 99             19          67                  Low              Medium
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# ...

# %% [markdown]
# # Conclusion
#
# This functions shows the first few rows of the dataset.If we want to check for any other rows, we can specify it by keeping the number in parenthesis

# %% [markdown]
# # Conclusion

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %% [markdown]
# # Conclusion
#
# It tells us the summary of mean, minimum, 50th and 75th percentile

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %% [markdown]
# # Conclusion
#
# It is used to count the bull values in a dataset.

# %%
df.count()
# Out:
# Hours_Studied                 6607
# Attendance                    6607
# Parental_Involvement          6607
# Access_to_Resources           6607
# Extracurricular_Activities    6607
# Sleep_Hours                   6607
# Previous_Scores               6607
# Motivation_Level              6607
# Internet_Access               6607
# Tutoring_Sessions             6607
# Family_Income                 6607
# Teacher_Quality               6529
# School_Type                   6607
# Peer_Influence                6607
# Physical_Activity             6607
# Learning_Disabilities         6607
# Parental_Education_Level      6517
# Distance_from_Home            6540
# Gender                        6607
# Exam_Score                    6607
# dtype: int64

# %% [markdown]
# # Conclusion
#
# This is used to count non-missing values in each coloumn.

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %% [markdown]
# # Conclusion
#
# This function is used to display the data types of each coloumn in a dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Conclusion
#
# Seaborn is used to create statistical graphs like histogram etc whereas matplotlib is used to created visualization. Both of these are the libraries

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data['Exam_Score'], kde=True, bins=10)  # kde=True adds a smooth curve
plt.title('Distribution of Exam Scores')
plt.xlabel('Exam Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Conclusion
#
# This graph tells that the scores are majorly around 65-70, that means that major number of students have scored marks in this particular interval. Since majority of the students have scored in this interval we can find a handfull of students in the intervals after 70 i.e; 80, 90 and 10, which tells us that very less students have scored well in the tests. The shape of the curve shows that majority of the students are clustered in the middle i.e; in the interval 65-70.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=data, x='Motivation_Level', y='Exam_Score')
plt.title('Exam Score by Motivation Level')
plt.xlabel('Motivation Level')
plt.ylabel('Exam Score')
plt.show()

# %% [markdown]
# # Conclusion
#
# This boxplot shows the distribution of exam scores .Motivational level shows that the exam scores does not vary with different levels of motivation. Also, motivational level is basically the measure of motivation, it is plotted to shows the ditribution. In this graph, the median scores are aoriund 70 only, the hight of each box is similar to each other.

# %%
mean_exam_score = df['Exam_Score'].mean()
median_exam_score = df['Exam_Score'].median()
std_exam_score = df['Exam_Score'].std() 

print("Mean of Exam Score: {:.2f}".format(mean_exam_score))
print("Median of Exam Score: {:.2f}".format(median_exam_score))
print("Standard Deviation of Exam Score: {:.2f}".format(std_exam_score))
# Out:
# Mean of Exam Score: 67.24
# Median of Exam Score: 67.00
# Standard Deviation of Exam Score: 3.89

# %% [markdown]
# # Conclusion
#
# We find mean to find the average value of the given data. Mode is taken out to find the highest frequency of the given data which is sorted and median is taken out to find the middle value of the given data which is sorted.

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("/kaggle/input/dataset2/StudentPerformanceFactors (1).csv")

# %%
Q1 = df['Exam_Score'].quantile(0.25)
Q3 = df['Exam_Score'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Exam_Score'] < lower_bound) | (df['Exam_Score'] > upper_bound)]
print("Outliers in Exam Score:")
print(outliers)
# Out:
# Outliers in Exam Score:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 94               18          89                 High              Medium
# 106              31         100               Medium              Medium
# 113              35          99                 High                High
# 209              43          86                 High              Medium
# 217              19          70               Medium                 Low
# ...             ...         ...                  ...                 ...
# 6347             28          96                 High                 Low
# 6393             16          83                  Low              Medium
# 6431              4          60               Medium              Medium
# 6522             18          90                 High                High
# 6566             29          96                 High              Medium
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mean_score = df['Exam_Score'].mean()
median_score = df['Exam_Score'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(df['Exam_Score'], kde=True, bins=10, color='skyblue', edgecolor='black')
plt.axvline(mean_score, color='red', linestyle='--', linewidth=1.5, label=f'Mean: {mean_score:.2f}')
plt.axvline(median_score, color='green', linestyle='-', linewidth=1.5, label=f'Median: {median_score:.2f}')
plt.title('Exam Score Distribution with Mean and Median')
plt.xlabel('Exam Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Conclusion
#
# We  can see that both mean and median are around 67.24 which shown in the graph by a green line. The above graph has a peak near centre which shows normal distribution. Talking about the score, majority of students have scored in the interval of 65-70.
